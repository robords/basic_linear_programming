# %%
from pulp import LpVariable, LpProblem, LpMaximize, LpStatus, value, LpMinimize, GLPK, PULP_CBC_CMD

# %% [markdown]
# __Part 1.__
#
# The Bavarian Motor Company (BMC) manufactures expensive luxury cars in Hamburg, Germany, and exports cars to sell in the United States. The exported cars are shipped from Hamburg to ports in Newark, New Jersey and Jacksonville, Florida. From these ports, the cars are transported by rail or truck to distributors located in Boston, Massachusetts; Columbus, Ohio; Atlanta, Georgia; Richmond, Virginia; and Mobile, Alabama. The below figure shows the possible shipping routes available to the company along with the transportation cost for shipping each car along the indicated path. Currently, 200 cars are available at the port in Newark and 300 are available in Jacksonville. The numbers of cars needed by the distributors in Boston, Columbus, Atlanta, Richmond, and Mobile are 100, 60, 170, 80, and 70, respectively. BMC wants to determine the least costly way of transporting cars from the ports in Newark and Jacksonville to the cities where they are needed.
#
# 1. Formulate the LP and solve it using software of your choice.
# 2. Conduct sensitivity analysis and interpret.
# 3. Provide the duals and demonstrate strong duality (i.e., complementary slackness).
#
# Strong duality, asserts that the minimal cost in the dual equals the maximal profit in the primal. (https://web.mit.edu/15.053/www/AMP-Chapter-04.pdf)
#
# ![alt text](network.png "BMC")

# %%
# Problem (BMC Problem)
# define variables
newark_port_to_boston_distributor = LpVariable("newark_port_transport_to_boston_distributor", 0, None)
newark_port_to_richmond_distributor = LpVariable("newark_port_transport_to_richmond_distributor", 0, None)
jacksonville_port_to_richmond_distributor = LpVariable("jacksonville_port_transport_to_richmond_distributor", 0, None)
jacksonville_port_to_mobile_distributor = LpVariable("jacksonville_port_transport_to_mobile_distributor", 0, None)
jacksonville_port_to_atlanta_distributor = LpVariable("jacksonville_port_transport_to_atlanta_distributor", 0, None)

boston_distributor_to_columbus_distributor = LpVariable("boston_distributor_transport_to_columbus_distributor", 0, None)
atlanta_distributor_to_richmond_distributor = LpVariable("atlanta_distributor_transport_to_richmond_distributor", 0, None)
atlanta_distributor_to_mobile_distributor = LpVariable("atlanta_distributor_transport_to_mobile_distributor", 0, None)
mobile_distributor_to_atlanta_distributor = LpVariable("mobile_distributor_transport_to_atlanta_distributor", 0, None)
atlanta_distributor_to_columbus_distributor = LpVariable("atlanta_distributor_transport_to_columbus_distributor", 0, None)
columbus_distributor_to_atlanta_distributor = LpVariable("columbus_distributor_transport_to_atlanta_distributor", 0, None)

# Total supply is 20 cars greater than demand at distributors
newark_port_to_dummy_distributor = LpVariable("newark_port_transport_to_dummy_distributor", 0, None)
jacksonville_port_to_dummy_distributor = LpVariable("jacksonville_port_transport_to_dummy_distributor", 0, None)

# defines the problem
bmc_problem = LpProblem("BMC Transport Problem", LpMinimize)

# define objective function
bmc_problem += (30*newark_port_to_boston_distributor + 
                40*newark_port_to_richmond_distributor + 
                50*jacksonville_port_to_richmond_distributor +
                50*jacksonville_port_to_mobile_distributor + 
                45*jacksonville_port_to_atlanta_distributor + 
                50*boston_distributor_to_columbus_distributor + 
                30*atlanta_distributor_to_richmond_distributor + 
                35*atlanta_distributor_to_mobile_distributor + 
                25*mobile_distributor_to_atlanta_distributor + 
                40*atlanta_distributor_to_columbus_distributor +
                35*columbus_distributor_to_atlanta_distributor)

# define constraints
# The numbers of cars needed by the distributors in 
# Boston, Columbus, Atlanta, Richmond, and Mobile are 100, 60, 170, 80, and 70, respectively

bmc_problem += (boston_distributor_to_columbus_distributor + atlanta_distributor_to_columbus_distributor -
                columbus_distributor_to_atlanta_distributor == 60, 
                '_60 Cars are Needed in Columbus')

bmc_problem += (newark_port_to_boston_distributor - boston_distributor_to_columbus_distributor >= 100, 
                '_100 Cars are Needed in Boston')

bmc_problem += (jacksonville_port_to_atlanta_distributor + mobile_distributor_to_atlanta_distributor -
                atlanta_distributor_to_richmond_distributor - atlanta_distributor_to_columbus_distributor - 
                atlanta_distributor_to_mobile_distributor == 170, 
                '_170 Cars are Needed in Atlanta')

bmc_problem += (jacksonville_port_to_richmond_distributor + newark_port_to_richmond_distributor +
                atlanta_distributor_to_richmond_distributor == 80, 
                '_80 Cars are Needed in Richmond')

bmc_problem += (jacksonville_port_to_mobile_distributor + atlanta_distributor_to_mobile_distributor -
                mobile_distributor_to_atlanta_distributor == 70, 
                '_70 Cars are Needed in Mobile')

# Currently, 200 cars are available at the port in Newark and 300 are available in Jacksonville
bmc_problem += (newark_port_to_boston_distributor + newark_port_to_richmond_distributor + 
                newark_port_to_dummy_distributor == 200, 
                '_200 cars are available at the port in Newark')

bmc_problem += (jacksonville_port_to_mobile_distributor + jacksonville_port_to_richmond_distributor + 
                jacksonville_port_to_atlanta_distributor + jacksonville_port_to_dummy_distributor == 300, 
                '_300 cars are available in Jacksonville')

## Greater than 0 constraints
for v in bmc_problem.variables():
    bmc_problem += (v >= 0, f"{v.name} Non-negative Constraint")

# solve the problem
bmc_problem.writeLP("bmc_problem.lp")

bmc_problem.solve(PULP_CBC_CMD(msg=0))
# Print the solution
print ("Status:", LpStatus[bmc_problem.status])
print(f"Minimum cost: {'${:,.2f}'.format(value(bmc_problem.objective))}")  ## formats automatically with commas at thou
for v in bmc_problem.variables():
    print(f'Number of {v.name} = {v.varValue + 0}') # + 0 ensures no negative zeros

bmc_problem.solve(GLPK(msg=1, options=['--ranges', 'bmc_problem.sen']))
print("Status:", LpStatus[bmc_problem.status])

# Note, we are only able to get sensitivity information because we are solving
# as a linear program.  If we solved as an Integer Program, then no 
# sensitivity information would be available.
for v in bmc_problem.variables():
    print(v.name, "=", v.varValue)
print ("Objective", value(bmc_problem.objective))
print ("")

f = open("bmc_problem.sen", "r")
print(f.read())
# Out:
# Status: Optimal
# Minimum cost: $22,350.00
# Number of atlanta_distributor_transport_to_columbus_distributor = 40.0
# Number of atlanta_distributor_transport_to_mobile_distributor = 0.0
# Number of atlanta_distributor_transport_to_richmond_distributor = 0.0
# Number of boston_distributor_transport_to_columbus_distributor = 20.0
# Number of columbus_distributor_transport_to_atlanta_distributor = 0.0
# Number of jacksonville_port_transport_to_atlanta_distributor = 210.0
# Number of jacksonville_port_transport_to_dummy_distributor = 20.0
# Number of jacksonville_port_transport_to_mobile_distributor = 70.0
# Number of jacksonville_port_transport_to_richmond_distributor = 0.0
# Number of mobile_distributor_transport_to_atlanta_distributor = 0.0
# Number of newark_port_transport_to_boston_distributor = 120.0
# Number of newark_port_transport_to_dummy_distributor = 0.0
# Number of newark_port_transport_to_richmond_distributor = 80.0
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /var/folders/c0/r6mf3b4n5w72sdb037sthl840000gn/T/0bcfa3eac3b04c7c9e2d6d6e3de416c6-pulp.lp
#  -o /var/folders/c0/r6mf3b4n5w72sdb037sthl840000gn/T/0bcfa3eac3b04c7c9e2d6d6e3de416c6-pulp.sol
#  --ranges bmc_problem.sen
# Reading problem data from '/var/folders/c0/r6mf3b4n5w72sdb037sthl840000gn/T/0bcfa3eac3b04c7c9e2d6d6e3de416c6-pulp.lp'...
# 20 rows, 13 columns, 36 non-zeros
# 71 lines were read
# GLPK Simplex Optimizer 5.0
# 20 rows, 13 columns, 36 non-zeros
# Preprocessing...
# 7 rows, 10 columns, 20 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 7
#       0: obj =   1.225000000e+04 inf =   1.600e+02 (2)
#       2: obj =   2.245000000e+04 inf =   0.000e+00 (0)
# *     4: obj =   2.235000000e+04 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.0 Mb (41607 bytes)
# Writing basic solution to '/var/folders/c0/r6mf3b4n5w72sdb037sthl840000gn/T/0bcfa3eac3b04c7c9e2d6d6e3de416c6-pulp.sol'...
# Write sensitivity analysis report to 'bmc_problem.sen'...
# Status: Optimal
# atlanta_distributor_transport_to_columbus_distributor = 40.0
# atlanta_distributor_transport_to_mobile_distributor = 0.0
# atlanta_distributor_transport_to_richmond_distributor = 0.0
# boston_distributor_transport_to_columbus_distributor = 20.0
# columbus_distributor_transport_to_atlanta_distributor = 0.0
# jacksonville_port_transport_to_atlanta_distributor = 210.0
# jacksonville_port_transport_to_dummy_distributor = 20.0
# jacksonville_port_transport_to_mobile_distributor = 70.0
# jacksonville_port_transport_to_richmond_distributor = 0.0
# mobile_distributor_transport_to_atlanta_distributor = 0.0
# newark_port_transport_to_boston_distributor = 120.0
# newark_port_transport_to_dummy_distributor = 0.0
# newark_port_transport_to_richmond_distributor = 80.0
# Objective 22350.0
#
# GLPK 5.0  - SENSITIVITY ANALYSIS REPORT                                                                         Page   1
#
# Problem:
# Objective:  OBJ = 22350 (MINimum)
#
#    No. Row name     St      Activity         Slack   Lower bound       Activity      Obj coef  Obj value at Limiting
#                                           Marginal   Upper bound          range         range   break point variable
# ------ ------------ -- ------------- ------------- -------------  ------------- ------------- ------------- ------------
#      1 _100_Cars_are_Needed_in_Boston
#                     NL     100.00000        .          100.00000       60.00000     -35.00000   20950.00000 atlanta_distributor_transport_to_columbus_distributor_Non_negative_Constraint
#                                           35.00000          +Inf      120.00000          +Inf   23050.00000 boston_distributor_transport_to_columbus_distributor_Non_negative_Constraint
#
#      2 _170_Cars_are_Needed_in_Atlanta
#                     NS     170.00000        .          170.00000      -40.00000          -Inf   12900.00000 jacksonville_port_transport_to_atlanta_distributor_Non_negative_Constraint
#                                           45.00000     170.00000      190.00000          +Inf   23250.00000 jacksonville_port_transport_to_dummy_distributor_Non_negative_Constraint
#
#      3 _200_cars_are_available_at_the_port_in_Newark
#                     NS     200.00000        .          200.00000      180.00000          -Inf   22450.00000 boston_distributor_transport_to_columbus_distributor_Non_negative_Constraint
#                                           -5.00000     200.00000      240.00000          +Inf   22150.00000 atlanta_distributor_transport_to_columbus_distributor_Non_negative_Constraint
#
#      4 _300_cars_are_available_in_Jacksonville
#                     NS     300.00000        .          300.00000      280.00000          -Inf   22350.00000 jacksonville_port_transport_to_dummy_distributor_Non_negative_Constraint
#                                             .          300.00000           +Inf          +Inf   22350.00000
#
#      5 _60_Cars_are_Needed_in_Columbus
#                     NS      60.00000        .           60.00000       20.00000          -Inf   18950.00000 atlanta_distributor_transport_to_columbus_distributor_Non_negative_Constraint
#                                           85.00000      60.00000       80.00000          +Inf   24050.00000 jacksonville_port_transport_to_dummy_distributor_Non_negative_Constraint
#
#      6 _70_Cars_are_Needed_in_Mobile
#                     NS      70.00000        .           70.00000         .               -Inf   18850.00000 jacksonville_port_transport_to_mobile_distributor_Non_negative_Constraint
#                                           50.00000      70.00000       90.00000          +Inf   23350.00000 jacksonville_port_transport_to_dummy_distributor_Non_negative_Constraint
#
#      7 _80_Cars_are_Needed_in_Richmond
#                     NS      80.00000        .           80.00000       40.00000          -Inf   20550.00000 atlanta_distributor_transport_to_columbus_distributor_Non_negative_Constraint
#                                           45.00000      80.00000      100.00000          +Inf   23250.00000 boston_distributor_transport_to_columbus_distributor_Non_negative_Constraint
#
#      8 atlanta_distributor_transport_to_columbus_distributor_Non_negative_Constraint
#                     BS      40.00000     -40.00000        .            60.00000      -5.00000   22150.00000 newark_port_transport_to_dummy_distributor
#                                             .               +Inf         .            5.00000   22550.00000 jacksonville_port_transport_to_richmond_distributor
#
#      9 atlanta_distributor_transport_to_mobile_distributor_Non_negative_Constraint
#                     BS        .             .             .            70.00000     -30.00000   22350.00000 atlanta_distributor_transport_to_mobile_distributor
#                                             .               +Inf         .               +Inf   22350.00000
#
#     10 atlanta_distributor_transport_to_richmond_distributor_Non_negative_Constraint
#                     BS        .             .             .            40.00000     -30.00000   22350.00000 atlanta_distributor_transport_to_richmond_distributor
#                                             .               +Inf         .               +Inf   22350.00000
#
# GLPK 5.0  - SENSITIVITY ANALYSIS REPORT                                                                         Page   2
#
# Problem:
# Objective:  OBJ = 22350 (MINimum)
#
#    No. Row name     St      Activity         Slack   Lower bound       Activity      Obj coef  Obj value at Limiting
#                                           Marginal   Upper bound          range         range   break point variable
# ------ ------------ -- ------------- ------------- -------------  ------------- ------------- ------------- ------------
#     11 boston_distributor_transport_to_columbus_distributor_Non_negative_Constraint
#                     BS      20.00000     -20.00000        .            60.00000      -5.00000   22250.00000 jacksonville_port_transport_to_richmond_distributor
#                                             .               +Inf         .            5.00000   22450.00000 newark_port_transport_to_dummy_distributor
#
#     12 columbus_distributor_transport_to_atlanta_distributor_Non_negative_Constraint
#                     BS        .             .             .            20.00000    -120.00000   22350.00000 columbus_distributor_transport_to_atlanta_distributor
#                                             .               +Inf         .               +Inf   22350.00000
#
#     13 jacksonville_port_transport_to_atlanta_distributor_Non_negative_Constraint
#                     BS     210.00000    -210.00000        .           230.00000      -5.00000   21300.00000 newark_port_transport_to_dummy_distributor
#                                             .               +Inf      170.00000       5.00000   23400.00000 jacksonville_port_transport_to_richmond_distributor
#
#     14 jacksonville_port_transport_to_dummy_distributor_Non_negative_Constraint
#                     BS      20.00000     -20.00000        .            20.00000          -Inf          -Inf
#                                             .               +Inf         .            5.00000   22450.00000 newark_port_transport_to_dummy_distributor
#
#     15 jacksonville_port_transport_to_mobile_distributor_Non_negative_Constraint
#                     BS      70.00000     -70.00000        .           280.00000     -30.00000   20250.00000 mobile_distributor_transport_to_atlanta_distributor
#                                             .               +Inf         .           30.00000   24450.00000 atlanta_distributor_transport_to_mobile_distributor
#
#     16 jacksonville_port_transport_to_richmond_distributor_Non_negative_Constraint
#                     BS        .             .             .            40.00000      -5.00000   22350.00000 jacksonville_port_transport_to_richmond_distributor
#                                             .               +Inf         .               +Inf   22350.00000
#
#     17 mobile_distributor_transport_to_atlanta_distributor_Non_negative_Constraint
#                     BS        .             .             .           210.00000     -30.00000   22350.00000 mobile_distributor_transport_to_atlanta_distributor
#                                             .               +Inf         .               +Inf   22350.00000
#
#     18 newark_port_transport_to_boston_distributor_Non_negative_Constraint
#                     BS     120.00000    -120.00000        .           160.00000      -5.00000   21750.00000 jacksonville_port_transport_to_richmond_distributor
#                                             .               +Inf      100.00000       5.00000   22950.00000 newark_port_transport_to_dummy_distributor
#
#     19 newark_port_transport_to_dummy_distributor_Non_negative_Constraint
#                     BS        .             .             .            20.00000      -5.00000   22350.00000 newark_port_transport_to_dummy_distributor
#                                             .               +Inf         .               +Inf   22350.00000
#
#     20 newark_port_transport_to_richmond_distributor_Non_negative_Constraint
#                     BS      80.00000     -80.00000        .            80.00000          -Inf          -Inf
#                                             .               +Inf       40.00000       5.00000   22750.00000 jacksonville_port_transport_to_richmond_distributor
#
# GLPK 5.0  - SENSITIVITY ANALYSIS REPORT                                                                         Page   3
#
# Problem:
# Objective:  OBJ = 22350 (MINimum)
#
#    No. Column name  St      Activity      Obj coef   Lower bound       Activity      Obj coef  Obj value at Limiting
#                                           Marginal   Upper bound          range         range   break point variable
# ------ ------------ -- ------------- ------------- -------------  ------------- ------------- ------------- ------------
#      1 atlanta_distributor_transport_to_columbus_distributor
#                     BS      40.00000      40.00000        .            60.00000      35.00000   22150.00000 newark_port_transport_to_dummy_distributor
#                                             .               +Inf         .           45.00000   22550.00000 jacksonville_port_transport_to_richmond_distributor
#
#      2 atlanta_distributor_transport_to_mobile_distributor
#                     NL        .           35.00000        .              .            5.00000   22350.00000 atlanta_distributor_transport_to_mobile_distributor_Non_negative_Constraint
#                                           30.00000          +Inf       70.00000          +Inf   24450.00000 jacksonville_port_transport_to_mobile_distributor_Non_negative_Constraint
#
#      3 atlanta_distributor_transport_to_richmond_distributor
#                     NL        .           30.00000        .              .             .        22350.00000 atlanta_distributor_transport_to_richmond_distributor_Non_negative_Constraint
#                                           30.00000          +Inf       40.00000          +Inf   23550.00000 atlanta_distributor_transport_to_columbus_distributor_Non_negative_Constraint
#
#      4 boston_distributor_transport_to_columbus_distributor
#                     BS      20.00000      50.00000        .            60.00000      45.00000   22250.00000 jacksonville_port_transport_to_richmond_distributor
#                                             .               +Inf         .           55.00000   22450.00000 newark_port_transport_to_dummy_distributor
#
#      5 columbus_distributor_transport_to_atlanta_distributor
#                     NL        .           35.00000        .              .          -85.00000   22350.00000 columbus_distributor_transport_to_atlanta_distributor_Non_negative_Constraint
#                                          120.00000          +Inf       20.00000          +Inf   24750.00000 jacksonville_port_transport_to_dummy_distributor_Non_negative_Constraint
#
#      6 jacksonville_port_transport_to_atlanta_distributor
#                     BS     210.00000      45.00000        .           230.00000      40.00000   21300.00000 newark_port_transport_to_dummy_distributor
#                                             .               +Inf      170.00000      50.00000   23400.00000 jacksonville_port_transport_to_richmond_distributor
#
#      7 jacksonville_port_transport_to_mobile_distributor
#                     BS      70.00000      50.00000        .           280.00000      20.00000   20250.00000 mobile_distributor_transport_to_atlanta_distributor
#                                             .               +Inf         .           80.00000   24450.00000 atlanta_distributor_transport_to_mobile_distributor
#
#      8 jacksonville_port_transport_to_richmond_distributor
#                     NL        .           50.00000        .              .           45.00000   22350.00000 jacksonville_port_transport_to_richmond_distributor_Non_negative_Constraint
#                                            5.00000          +Inf       40.00000          +Inf   22550.00000 atlanta_distributor_transport_to_columbus_distributor_Non_negative_Constraint
#
#      9 mobile_distributor_transport_to_atlanta_distributor
#                     NL        .           25.00000        .              .           -5.00000   22350.00000 mobile_distributor_transport_to_atlanta_distributor_Non_negative_Constraint
#                                           30.00000          +Inf      210.00000          +Inf   28650.00000 jacksonville_port_transport_to_atlanta_distributor_Non_negative_Constraint
#
#     10 newark_port_transport_to_boston_distributor
#                     BS     120.00000      30.00000        .           160.00000      25.00000   21750.00000 jacksonville_port_transport_to_richmond_distributor
#                                             .               +Inf      100.00000      35.00000   22950.00000 newark_port_transport_to_dummy_distributor
#
# GLPK 5.0  - SENSITIVITY ANALYSIS REPORT                                                                         Page   4
#
# Problem:
# Objective:  OBJ = 22350 (MINimum)
#
#    No. Column name  St      Activity      Obj coef   Lower bound       Activity      Obj coef  Obj value at Limiting
#                                           Marginal   Upper bound          range         range   break point variable
# ------ ------------ -- ------------- ------------- -------------  ------------- ------------- ------------- ------------
#     11 newark_port_transport_to_richmond_distributor
#                     BS      80.00000      40.00000        .            80.00000          -Inf          -Inf
#                                             .               +Inf       40.00000      45.00000   22750.00000 jacksonville_port_transport_to_richmond_distributor
#
#     12 newark_port_transport_to_dummy_distributor
#                     NL        .             .             .              .           -5.00000   22350.00000 newark_port_transport_to_dummy_distributor_Non_negative_Constraint
#                                            5.00000          +Inf       20.00000          +Inf   22450.00000 boston_distributor_transport_to_columbus_distributor_Non_negative_Constraint
#
#     13 jacksonville_port_transport_to_dummy_distributor
#                     BS      20.00000        .             .            20.00000          -Inf          -Inf
#                                             .               +Inf         .            5.00000   22450.00000 newark_port_transport_to_dummy_distributor
#
# End of report
